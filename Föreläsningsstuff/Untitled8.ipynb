# %% [markdown]
# ## import math

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
em7b5 = np.array([329,493,783,587])
Eb7 = np.array([311,392,466,554])
dm6 = np.array([293,349,440,493])

fs = 48000
sec = 3

oneNote = np.linspace(0,sec,sec*fs,False)

chords = [ [np.sin(note*oneNote*2*np.pi) for note in chord] for chord in [em7b5,Eb7,dm6] ]
chords2 = np.array(list(map(lambda chord: chord[0]+chord[1]+chord[2]+chord[3]/4,chords))).flatten()

# %%
np.array(np.sin(440*oneNote*2*np.pi))
fl = list(map(float,np.array(np.sin(440*oneNote*2*np.pi))))

# %%
f = open("output2.bin","w")
t = [x.astype('>f4').tobytes() for x in np.array(fl)]
for e in t:
    f.writelines(str(e))

# %%
plt.plot(chords[0], "g", label="Sin")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      75         try:
# ---> 76             reduction = getattr(obj, method)
#      77         except AttributeError:
#
# AttributeError: 'bool' object has no attribute 'any'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-07a60200a256> in <module>
# ----> 1 plt.plot(chords[0], "g", label="Sin")
#
# ~/.anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
# ...

# %%
chords
# Out:
# [[array([ 0.        ,  0.04305269,  0.08602554, ..., -0.12883887,
#          -0.08602554, -0.04305269]),
#   array([ 0.        ,  0.06448877,  0.12870906, ..., -0.19239351,
#          -0.12870906, -0.06448877]),
#   array([ 0.        ,  0.1023151 ,  0.20355631, ..., -0.30266101,
#          -0.20355631, -0.1023151 ]),
#   array([ 0.        ,  0.07676253,  0.15307207, ..., -0.22847831,
#          -0.15307207, -0.07676253])],
#  [array([ 0.        ,  0.04069856,  0.08132968, ..., -0.12182604,
#          -0.08132968, -0.04069856]),
#   array([ 0.        ,  0.05129017,  0.10244531, ..., -0.15333078,
#          -0.10244531, -0.05129017]),
#   array([ 0.        ,  0.06096144,  0.12169611, ..., -0.1819781 ,
#          -0.12169611, -0.06096144]),
#   array([ 0.        ,  0.07245489,  0.1445289 , ..., -0.21584319,
#          -0.1445289 , -0.07245489])],
#  [array([ 0.        ,  0.03834421,  0.07663202, ..., -0.11480712,
#          -0.07663202, -0.03834421]),
# ...

# %%
audio = note * (2**15-1) / np.max(np.abs(note))
audio = audio.astype(np.int16)

# %%
play = sa.pl
# Out:
# array([ 0.        ,  0.06264832,  0.12505052, ..., -0.18696144,
#        -0.12505052, -0.06264832])

# %%
f = open("demo.bin","a")
f.write([math.sin(x*0.01) for x in range(0,48000)])
f.close
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3edef41ec695> in <module>
#       1 f = open("demo.bin","a")
# ----> 2 f.write([math.sin(x*0.01) for x in range(0,48000)])
#       3 f.close
#
# TypeError: write() argument must be str, not list
